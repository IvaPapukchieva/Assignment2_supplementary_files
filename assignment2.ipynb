# %%
# !pip3 install rdflib pandas -U -q

import pandas as pd # for loading CSV
from rdflib import Graph, Literal, Namespace,URIRef
from rdflib.namespace import RDF, RDFS, XSD, SDO, OWL

# %%
# populate the graph 
g = Graph()
# load the schema 
g.parse("Bookshop.ttl", format="ttl")
print(g.serialize(format="ttl"))
# Out:
# @prefix : <http://example.org/bookshop#> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix schema: <https://schema.org/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# :Basket a rdfs:Class ;
#     rdfs:label "Basket" ;
#     rdfs:comment "Shopping cart which contains products during shopping." .
#
# :ChildrensBook a rdfs:Class ;
#     rdfs:label "Children’sBook" ;
#     rdfs:comment "A book in genre recommended for children." ;
#     rdfs:subClassOf :Genre .
#
# :Discount a rdfs:Class ;
#     rdfs:label "Discount" ;
#     rdfs:comment "A reduction of price of the product." .
#
# :Fantasy a rdfs:Class ;
#     rdfs:label "Fantasy" ;
#     rdfs:comment """Type of general fiction which includes supernatural elements.
# """ ;
#     rdfs:subClassOf :GeneralFiction .
#
# :Games a rdfs:Class ;
#     rdfs:label "Games" ;
#     rdfs:comment "Game possible to purchase in the shop." ;
#     rdfs:subClassOf schema:Product .
#
# :GeneralFiction a rdfs:Class ;
#     rdfs:label "GeneralFiction" ;
#     rdfs:comment "A category of genres which includes fiction stories. " ;
#     rdfs:subClassOf :Genre .
#
# :Genre a rdfs:Class ;
#     rdfs:label "Genre" ;
#     rdfs:comment "Classifies books to the type based on what topic are they about." .
#
# :Horror a rdfs:Class ;
#     rdfs:label "Horror" ;
#     rdfs:comment "Type of general fiction which includes scary stories." ;
#     rdfs:subClassOf :GeneralFiction .
#
# :Mathematics a rdfs:Class ;
#     rdfs:label "Mathematics" ;
#     rdfs:comment "Type of non-fiction which is about the topic of mathematics." ;
#     rdfs:subClassOf :Non-fiction .
#
# :Non-fiction a rdfs:Class ;
#     rdfs:label "Non-fiction" ;
#     rdfs:comment "A category of genres which includes real facts and true events." ;
#     rdfs:subClassOf :Genre .
#
# :Philosophy a rdfs:Class ;
#     rdfs:label "Philosophy" ;
#     rdfs:comment "Type of non-fiction which is about the topic of philosophy." ;
#     rdfs:subClassOf :Non-fiction .
#
# :Romance a rdfs:Class ;
#     rdfs:label "Romance" ;
#     rdfs:comment "Type of general fiction which includes romantic stories." ;
#     rdfs:subClassOf :GeneralFiction .
#
# :Travel a rdfs:Class ;
#     rdfs:label "Travel" ;
#     rdfs:comment "Type of non-fiction which is about the topic of traveling." ;
#     rdfs:subClassOf :Non-fiction .
#
# schema:Book a rdfs:Class ;
#     rdfs:label "Book" ;
#     rdfs:comment "Book possible to purchase in the shop." ;
#     rdfs:subClassOf schema:Product .
#
# schema:Order a rdfs:Class ;
#     rdfs:label "Order" ;
#     rdfs:comment "A customer order which contains products." .
#
# schema:Person a rdfs:Class ;
#     rdfs:label "Person" ;
#     rdfs:comment "A person which might be a customer of the shop or an author of a book." .
#
# schema:Product a rdfs:Class ;
#     rdfs:label "Product" ;
#     rdfs:comment "A product possible to purchase in the book shop." .
#
# schema:address a rdfs:Class ;
#     rdfs:label "Address" ;
#     rdfs:comment "A postal address used for delivering products." .
#
# schema:author a rdfs:Class ;
#     rdfs:label "Author" ;
#     rdfs:comment "An author who wrote a book." ;
#     rdfs:subClassOf schema:Person .
#
# schema:customer a rdfs:Class ;
#     rdfs:label "Customer" ;
#     rdfs:comment "A person who purchases products from the shop." ;
#     rdfs:subClassOf schema:Person .
#
# schema:publisher a rdfs:Class ;
#     rdfs:label "Publisher" ;
#     rdfs:comment "A publisher who takes care of releasing a product. " .
#
# :basketContains a rdfs:Property ;
#     rdfs:label "basketContains" ;
#     rdfs:comment "Relates the basket to the products which customer wants to purchase." ;
#     rdfs:domain :Basket ;
#     rdfs:range schema:Product .
#
# :belongsToGenre a rdfs:Property ;
#     rdfs:label "belongsToGenre" ;
#     rdfs:comment "Relates a book to its genre." ;
#     rdfs:domain :Book ;
#     rdfs:range :Genre .
#
# :bookISBN a rdfs:Property ;
#     rdfs:label "bookISBN" ;
#     rdfs:comment "The ISBN number of the book (officially defined as a string)." ;
#     rdfs:domain :Book ;
#     rdfs:range xsd:string .
#
# :bookTitle a rdfs:Property ;
#     rdfs:label "bookTitle" ;
#     rdfs:comment "The textual title of the book." ;
#     rdfs:domain :Book ;
#     rdfs:range xsd:string .
#
# :description a rdfs:Property ;
#     rdfs:label "description" ;
#     rdfs:comment "Textual description on what the book is about." ;
#     rdfs:domain :Product ;
#     rdfs:range xsd:string .
#
# :hasAddress a rdfs:Property ;
#     rdfs:label "hasAddress" ;
#     rdfs:comment "Relates the customer to the address for delivery." ;
#     rdfs:domain :Customer ;
#     rdfs:range schema:address .
#
# :hasDiscount a rdfs:Property ;
#     rdfs:label "hasDiscount" ;
#     rdfs:comment "Relates the product to the discount that is applicable to it." ;
#     rdfs:domain :Product ;
#     rdfs:range :Discount .
#
# :isAuthorOf a rdfs:Property ;
#     rdfs:label "isAuthorOf" ;
#     rdfs:comment "Relates the author to the book that they have written." ;
#     rdfs:domain :Author ;
#     rdfs:range schema:Book .
#
# :numberOfPages a rdfs:Property ;
#     rdfs:label "numberOfPages" ;
#     rdfs:comment "Integer number of pages that the book has." ;
#     rdfs:domain :Book ;
#     rdfs:range xsd:integer .
#
# :orderContains a rdfs:Property ;
#     rdfs:label "orderContains" ;
#     rdfs:comment "Relates the basket to the products which customer purchased." ;
#     rdfs:domain :Order ;
#     rdfs:range schema:Product .
#
# :placesOrder a rdfs:Property ;
#     rdfs:label "placesOrder" ;
#     rdfs:comment "Relates the customer to the order that they have placed." ;
#     rdfs:domain :Customer ;
#     rdfs:range schema:Order .
#
# :price a rdfs:Property ;
#     rdfs:label "price" ;
#     rdfs:comment "The monetary price of the book." ;
#     rdfs:domain :Product ;
#     rdfs:range xsd:decimal .
#
# :publishedBy a rdfs:Property ;
#     rdfs:label "publishedBy" ;
#     rdfs:comment "Relates the product to the publisher which published it." ;
#     rdfs:domain :Product ;
#     rdfs:range schema:publisher .
#
# :publishedOn a rdfs:Property ;
#     rdfs:label "publishedOn" ;
#     rdfs:comment "The date on which the product was published." ;
#     rdfs:domain :Product ;
#     rdfs:range xsd:date .
#
# <https://w3id.org/sulo/schema/resource/ontology-schema/e2973675-d52e-4cbc-b30c-ada508eb2456> dct:title "Bookshop" .

# %%
BOOKSHOP = Namespace("http://example.org/bookshop#")
SCHEMA = Namespace("https://schema.org/")

g.bind("items", BOOKSHOP)
g.bind("sdo", SDO)
g.bind("rdfs", RDFS)
g.bind("owl", OWL)

# %%
df = pd.read_csv("group_10_ken3140_webshop - Sheet1.csv").dropna()
print(f"Removed {1000-len(df)} rows with empty cells.")

# Select the columns of interest
selected_columns = [
    "Item Name",
    "Item URL",
    "Item URI",
    "Category",
    "Subcategory",
    "Publisher",
    "Attribute 1",
    "Value 1",
    "Schema URI 1",
    "Attribute 2",
    "Value 2",
    "Schema URI 2",
    "Attribute 3",
    "Value 3",
    "Schema URI 3",
    "Attribute 4",
    "Value 4",
    "URI 4",
    "Attribute 5",
    "Value 5",
    "URI 5"
]
df
# Out:
# Removed 987 rows with empty cells.
#                         Item Name                                           Item URL                                           Item URI Category Subcategory  \
# 0                        The Deal  https://blackwells.co.uk/bookshop/product/The-...  http://example.org/webshop/the-deal-9780349447155     Book     Romance
# 1          Burn of the Everflame   https://blackwells.co.uk/bookshop/product/Burn...  http://example.org/webshop/burn-of-the-flame-9...     Book     Romance
# 2             The Poison Daughter  https://blackwells.co.uk/bookshop/product/The-...  http://example.org/webshop/the-poison-daughter...     Book     Romance
# 3                       The Girls  https://blackwells.co.uk/bookshop/product/The-...  http://example.org/webshop/the-girls-978152997...     Book     Romance
# 4   The Ballad of Falling Dragons  https://blackwells.co.uk/bookshop/product/The-...  http://example.org/webshop/the-ballad-of-falli...     Book     Romance
# 5                        Pink Ink  https://blackwells.co.uk/bookshop/product/Pink...  http://example.org/webshop/pink-ink-9781668218983     Book     Romance
# 6                    Twisted Lies  https://blackwells.co.uk/bookshop/product/Twis...  http://example.org/webshop/twisted-lies-978034...     Book     Romance
# 7                     Daggermouth  https://blackwells.co.uk/bookshop/product/Dagg...  http://example.org/webshop/daggermouth-9798347...     Book     Romance
# 8                       Riftborne  https://blackwells.co.uk/bookshop/product/Rift...  http://example.org/webshop/riftborne-978024181...     Book     Romance
# 9                           Smoke  https://blackwells.co.uk/bookshop/product/Smok...     http://example.org/webshop/smoke-9798896230441     Book     Romance
# 10                             It  https://blackwells.co.uk/bookshop/product/IT-b...       http://example.org/webshop/it-99781399761550     Book      Horror
# 11                           Fawn  https://blackwells.co.uk/bookshop/product/Fawn...      http://example.org/webshop/fawn-9780857508805     Book      Horror
# 12                   Solace House  https://blackwells.co.uk/bookshop/product/Sola...  http://example.org/webshop/solace-house-210000...     Book      Horror
#
#                              Publisher Attribute 1                         Value 1             Schema URI 1 Attribute 2  ...               Schema URI 2 Attribute 3  \
# 0                        Little, Brown         name                       The Deal  https://schema.org/name      author  ...  https://schema.org/author       price
# 1            Headline Publishing Group         name          Burn of the Everflame  https://schema.org/name      author  ...  https://schema.org/author       price
# 2                           Transworld         name            The Poison Daughter  https://schema.org/name      author  ...  https://schema.org/author       price
# 3                         Random House         name                      The Girls  https://schema.org/name      author  ...  https://schema.org/author       price
# 4             HarperCollins Publishers         name  The Ballad of Falling Dragons  https://schema.org/name      author  ...  https://schema.org/author       price
# 5                        Gallery Books         name                       Pink Ink  https://schema.org/name      author  ...  https://schema.org/author       price
# 6                        Little, Brown         name                   Twisted Lies  https://schema.org/name      author  ...  https://schema.org/author       price
# 7                       Scarlett Press         name                    Daggermouth  https://schema.org/name      author  ...  https://schema.org/author       price
# 8   Penguin Random House Children's UK         name                      Riftborne  https://schema.org/name      author  ...  https://schema.org/author       price
# 9                New York Review Books         name                          Smoke  https://schema.org/name      author  ...  https://schema.org/author       price
# 10                  Hodder & Stoughton         name                             It  https://schema.org/name      author  ...  https://schema.org/author       price
# 11                          Transworld         name                           Fawn  https://schema.org/name      author  ...  https://schema.org/author       price
# 12                      Atlantic Books         name                   Solace House  https://schema.org/name      author  ...  https://schema.org/author       price
#
#    Value 3              Schema URI 3    Attribute 4 Value 4                             URI 4    Attribute 5     Value 5                             URI 5
# 0    27,14  https://schema.org/price  numberOfPages     389  https://schema.org/numberOfPages  datePublished  2025-11-13  https://schema.org/datePublished
# 1    19,66  https://schema.org/price  numberOfPages     848  https://schema.org/numberOfPages  datePublished  2026-09-08  https://schema.org/datePublished
# 2    29,36  https://schema.org/price  numberOfPages     656  https://schema.org/numberOfPages  datePublished  2026-08-18  https://schema.org/datePublished
# 3     18,4  https://schema.org/price  numberOfPages     240  https://schema.org/numberOfPages  datePublished  2026-06-04  https://schema.org/datePublished
# 4    31,75  https://schema.org/price  numberOfPages     576  https://schema.org/numberOfPages  datePublished  2026-11-05  https://schema.org/datePublished
# 5    22,30  https://schema.org/price  numberOfPages     400  https://schema.org/numberOfPages  datePublished  2026-08-13  https://schema.org/datePublished
# 6    28,31  https://schema.org/price  numberOfPages     554  https://schema.org/numberOfPages  datePublished  2026-07-30  https://schema.org/datePublished
# 7    33,30  https://schema.org/price  numberOfPages     400  https://schema.org/numberOfPages  datePublished  2026-07-28  https://schema.org/datePublished
# 8    27,45  https://schema.org/price  numberOfPages     432  https://schema.org/numberOfPages  datePublished  2026-04-23  https://schema.org/datePublished
# 9    23,43  https://schema.org/price  numberOfPages     272  https://schema.org/numberOfPages  datePublished  2026-07-14  https://schema.org/datePublished
# 10   35,15  https://schema.org/price  numberOfPages    1088  https://schema.org/numberOfPages  datePublished  2026-09-03  https://schema.org/datePublished
# 11   27,40  https://schema.org/price  numberOfPages     368  https://schema.org/numberOfPages  datePublished  2026-08-27  https://schema.org/datePublished
# 12   23,30  https://schema.org/price  numberOfPages     512  https://schema.org/numberOfPages  datePublished  2026-05-07  https://schema.org/datePublished
#
# [13 rows x 21 columns]

# %%
def create_uri(input_string):
  """
  Creates a URI from an input string
  """
  import re
  cleaned_string = re.sub(r'[^\w]', '', input_string)
  uri_string = BOOKSHOP[cleaned_string]
  return uri_string

test_uri_1 = create_uri("The Godfather: Part II")
test_uri_2 = create_uri("Francis Ford Coppola")
print(test_uri_1, test_uri_2)
# Out:
# http://example.org/bookshop#TheGodfatherPartII http://example.org/bookshop#FrancisFordCoppola

# %%
for index, row in df.iterrows():

    # Individual product
    item_uri = URIRef(row["Item URI"])

    # Product's subcategory
    subcategory_uri = BOOKSHOP[row["Subcategory"]]
    g.add((item_uri, RDF.type, subcategory_uri))

    # Product URL
    g.add((item_uri, SCHEMA.url, URIRef(row["Item URL"])))

    # Publisher
    publisher_uri = BOOKSHOP[
        str(row["Publisher"]).replace(" ", "_")
    ]

    g.add((publisher_uri, RDF.type, BOOKSHOP.Publisher))
    g.add((item_uri, BOOKSHOP.publishedBy, publisher_uri))

    # Five attributes
    for i in range(1, 6):

        value = row[f"Value {i}"]

        if i <= 3:
            property_uri = URIRef(row[f"Schema URI {i}"])
        else:
            property_uri = URIRef(row[f"URI {i}"])

        g.add((item_uri, property_uri, Literal(value)))

print(g.serialize(format="ttl"))
# Out:
# @prefix : <http://example.org/bookshop#> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix items: <http://example.org/bookshop#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix schema: <https://schema.org/> .
# @prefix sdo: <https://schema.org/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# :Basket a rdfs:Class ;
#     rdfs:label "Basket" ;
#     rdfs:comment "Shopping cart which contains products during shopping." .
#
# :ChildrensBook a rdfs:Class ;
#     rdfs:label "Children’sBook" ;
#     rdfs:comment "A book in genre recommended for children." ;
#     rdfs:subClassOf :Genre .
#
# :Discount a rdfs:Class ;
#     rdfs:label "Discount" ;
#     rdfs:comment "A reduction of price of the product." .
#
# :Fantasy a rdfs:Class ;
#     rdfs:label "Fantasy" ;
#     rdfs:comment """Type of general fiction which includes supernatural elements.
# """ ;
#     rdfs:subClassOf :GeneralFiction .
#
# :Games a rdfs:Class ;
#     rdfs:label "Games" ;
#     rdfs:comment "Game possible to purchase in the shop." ;
#     rdfs:subClassOf schema:Product .
#
# :GeneralFiction a rdfs:Class ;
#     rdfs:label "GeneralFiction" ;
#     rdfs:comment "A category of genres which includes fiction stories. " ;
#     rdfs:subClassOf :Genre .
#
# :Genre a rdfs:Class ;
#     rdfs:label "Genre" ;
#     rdfs:comment "Classifies books to the type based on what topic are they about." .
#
# :Horror a rdfs:Class ;
#     rdfs:label "Horror" ;
#     rdfs:comment "Type of general fiction which includes scary stories." ;
#     rdfs:subClassOf :GeneralFiction .
#
# :Mathematics a rdfs:Class ;
#     rdfs:label "Mathematics" ;
#     rdfs:comment "Type of non-fiction which is about the topic of mathematics." ;
#     rdfs:subClassOf :Non-fiction .
#
# :Non-fiction a rdfs:Class ;
#     rdfs:label "Non-fiction" ;
#     rdfs:comment "A category of genres which includes real facts and true events." ;
#     rdfs:subClassOf :Genre .
#
# :Philosophy a rdfs:Class ;
#     rdfs:label "Philosophy" ;
#     rdfs:comment "Type of non-fiction which is about the topic of philosophy." ;
#     rdfs:subClassOf :Non-fiction .
#
# :Romance a rdfs:Class ;
#     rdfs:label "Romance" ;
#     rdfs:comment "Type of general fiction which includes romantic stories." ;
#     rdfs:subClassOf :GeneralFiction .
#
# :Travel a rdfs:Class ;
#     rdfs:label "Travel" ;
#     rdfs:comment "Type of non-fiction which is about the topic of traveling." ;
#     rdfs:subClassOf :Non-fiction .
#
# schema:Book a rdfs:Class ;
#     rdfs:label "Book" ;
#     rdfs:comment "Book possible to purchase in the shop." ;
#     rdfs:subClassOf schema:Product .
#
# schema:Order a rdfs:Class ;
#     rdfs:label "Order" ;
#     rdfs:comment "A customer order which contains products." .
#
# schema:Person a rdfs:Class ;
#     rdfs:label "Person" ;
#     rdfs:comment "A person which might be a customer of the shop or an author of a book." .
#
# schema:Product a rdfs:Class ;
#     rdfs:label "Product" ;
#     rdfs:comment "A product possible to purchase in the book shop." .
#
# schema:address a rdfs:Class ;
#     rdfs:label "Address" ;
#     rdfs:comment "A postal address used for delivering products." .
#
# schema:author a rdfs:Class ;
#     rdfs:label "Author" ;
#     rdfs:comment "An author who wrote a book." ;
#     rdfs:subClassOf schema:Person .
#
# schema:customer a rdfs:Class ;
#     rdfs:label "Customer" ;
#     rdfs:comment "A person who purchases products from the shop." ;
#     rdfs:subClassOf schema:Person .
#
# schema:publisher a rdfs:Class ;
#     rdfs:label "Publisher" ;
#     rdfs:comment "A publisher who takes care of releasing a product. " .
#
# :basketContains a rdfs:Property ;
#     rdfs:label "basketContains" ;
#     rdfs:comment "Relates the basket to the products which customer wants to purchase." ;
#     rdfs:domain :Basket ;
#     rdfs:range schema:Product .
#
# :belongsToGenre a rdfs:Property ;
#     rdfs:label "belongsToGenre" ;
#     rdfs:comment "Relates a book to its genre." ;
#     rdfs:domain :Book ;
#     rdfs:range :Genre .
#
# :bookISBN a rdfs:Property ;
#     rdfs:label "bookISBN" ;
#     rdfs:comment "The ISBN number of the book (officially defined as a string)." ;
#     rdfs:domain :Book ;
#     rdfs:range xsd:string .
#
# :bookTitle a rdfs:Property ;
#     rdfs:label "bookTitle" ;
#     rdfs:comment "The textual title of the book." ;
#     rdfs:domain :Book ;
#     rdfs:range xsd:string .
#
# :description a rdfs:Property ;
#     rdfs:label "description" ;
#     rdfs:comment "Textual description on what the book is about." ;
#     rdfs:domain :Product ;
#     rdfs:range xsd:string .
#
# :hasAddress a rdfs:Property ;
#     rdfs:label "hasAddress" ;
#     rdfs:comment "Relates the customer to the address for delivery." ;
#     rdfs:domain :Customer ;
#     rdfs:range schema:address .
#
# :hasDiscount a rdfs:Property ;
#     rdfs:label "hasDiscount" ;
#     rdfs:comment "Relates the product to the discount that is applicable to it." ;
#     rdfs:domain :Product ;
#     rdfs:range :Discount .
#
# :isAuthorOf a rdfs:Property ;
#     rdfs:label "isAuthorOf" ;
#     rdfs:comment "Relates the author to the book that they have written." ;
#     rdfs:domain :Author ;
#     rdfs:range schema:Book .
#
# :numberOfPages a rdfs:Property ;
#     rdfs:label "numberOfPages" ;
#     rdfs:comment "Integer number of pages that the book has." ;
#     rdfs:domain :Book ;
#     rdfs:range xsd:integer .
#
# :orderContains a rdfs:Property ;
#     rdfs:label "orderContains" ;
#     rdfs:comment "Relates the basket to the products which customer purchased." ;
#     rdfs:domain :Order ;
#     rdfs:range schema:Product .
#
# :placesOrder a rdfs:Property ;
#     rdfs:label "placesOrder" ;
#     rdfs:comment "Relates the customer to the order that they have placed." ;
#     rdfs:domain :Customer ;
#     rdfs:range schema:Order .
#
# :price a rdfs:Property ;
#     rdfs:label "price" ;
#     rdfs:comment "The monetary price of the book." ;
#     rdfs:domain :Product ;
#     rdfs:range xsd:decimal .
#
# :publishedBy a rdfs:Property ;
#     rdfs:label "publishedBy" ;
#     rdfs:comment "Relates the product to the publisher which published it." ;
#     rdfs:domain :Product ;
#     rdfs:range schema:publisher .
#
# :publishedOn a rdfs:Property ;
#     rdfs:label "publishedOn" ;
#     rdfs:comment "The date on which the product was published." ;
#     rdfs:domain :Product ;
#     rdfs:range xsd:date .
#
# <http://example.org/webshop/burn-of-the-flame-9781035432523> a :Romance ;
#     :publishedBy items:Headline_Publishing_Group ;
#     schema:author "Penn Cole" ;
#     sdo:datePublished "2026-09-08" ;
#     sdo:name "Burn of the Everflame" ;
#     sdo:numberOfPages 848 ;
#     sdo:price "19,66" ;
#     sdo:url <https://blackwells.co.uk/bookshop/product/Burn-of-the-Everflame-by-Penn-Cole/9781035432523> .
#
# <http://example.org/webshop/daggermouth-9798347122363> a :Romance ;
#     :publishedBy items:Scarlett_Press ;
#     schema:author "H. M. Wolfe" ;
#     sdo:datePublished "2026-07-28" ;
#     sdo:name "Daggermouth" ;
#     sdo:numberOfPages 400 ;
#     sdo:price "33,30" ;
#     sdo:url <https://blackwells.co.uk/bookshop/product/Daggermouth-by-H-M-Wolfe/9798347122363> .
#
# <http://example.org/webshop/fawn-9780857508805> a :Horror ;
#     :publishedBy items:Transworld ;
#     schema:author "C. N. Vair" ;
#     sdo:datePublished "2026-08-27" ;
#     sdo:name "Fawn" ;
#     sdo:numberOfPages 368 ;
#     sdo:price "27,40" ;
#     sdo:url <https://blackwells.co.uk/bookshop/product/Fawn-by-C-N-Vair/9780857508805> .
#
# <http://example.org/webshop/it-99781399761550> a :Horror ;
#     :publishedBy <http://example.org/bookshop#Hodder_&_Stoughton> ;
#     schema:author "Stephen King" ;
#     sdo:datePublished "2026-09-03" ;
#     sdo:name "It" ;
#     sdo:numberOfPages 1088 ;
#     sdo:price "35,15" ;
#     sdo:url <https://blackwells.co.uk/bookshop/product/IT-by-Stephen-King/9781399761550> .
#
# <http://example.org/webshop/pink-ink-9781668218983> a :Romance ;
#     :publishedBy items:Gallery_Books ;
#     schema:author "Avina St. Graves" ;
#     sdo:datePublished "2026-08-13" ;
#     sdo:name "Pink Ink" ;
#     sdo:numberOfPages 400 ;
#     sdo:price "22,30" ;
#     sdo:url <https://blackwells.co.uk/bookshop/product/Pink-Ink-by-Avina-St-Graves/9781668218983> .
#
# <http://example.org/webshop/riftborne-9780241818657> a :Romance ;
#     :publishedBy <http://example.org/bookshop#Penguin_Random_House_Children's_UK> ;
#     schema:author "Bree Grenwich, Parker Lennox" ;
#     sdo:datePublished "2026-04-23" ;
#     sdo:name "Riftborne" ;
#     sdo:numberOfPages 432 ;
#     sdo:price "27,45" ;
#     sdo:url <https://blackwells.co.uk/bookshop/product/Riftborne-by-Bree-Grenwich-Parker-Lennox/9780241818657> .
#
# <http://example.org/webshop/smoke-9798896230441> a :Romance ;
#     :publishedBy items:New_York_Review_Books ;
#     schema:author "Ivan Sergeevich Turgenev" ;
#     sdo:datePublished "2026-07-14" ;
#     sdo:name "Smoke" ;
#     sdo:numberOfPages 272 ;
#     sdo:price "23,43" ;
#     sdo:url <https://blackwells.co.uk/bookshop/product/Smoke-by-Ivan-Sergeevich-Turgenev-author-Donald-Rayfield-translator/9798896230441> .
#
# <http://example.org/webshop/solace-house-2100000300747> a :Horror ;
#     :publishedBy items:Atlantic_Books ;
#     schema:author "Will Maclean" ;
#     sdo:datePublished "2026-05-07" ;
#     sdo:name "Solace House" ;
#     sdo:numberOfPages 512 ;
#     sdo:price "23,30" ;
#     sdo:url <https://blackwells.co.uk/bookshop/product/Solace-House-by-Will-Maclean/2100000300747> .
#
# <http://example.org/webshop/the-ballad-of-falling-dragons-9780008838126> a :Romance ;
#     :publishedBy items:HarperCollins_Publishers ;
#     schema:author "Sarah A. Parker" ;
#     sdo:datePublished "2026-11-05" ;
#     sdo:name "The Ballad of Falling Dragons" ;
#     sdo:numberOfPages 576 ;
#     sdo:price "31,75" ;
#     sdo:url <https://blackwells.co.uk/bookshop/product/The-Ballad-of-Falling-Dragons-by-Sarah-A-Parker/9780008838126> .
#
# <http://example.org/webshop/the-deal-9780349447155> a :Romance ;
#     :publishedBy <http://example.org/bookshop#Little,_Brown> ;
#     schema:author "Elle Kennedy" ;
#     sdo:datePublished "2025-11-13" ;
#     sdo:name "The Deal" ;
#     sdo:numberOfPages 389 ;
#     sdo:price "27,14" ;
#     sdo:url <https://blackwells.co.uk/bookshop/product/The-Deal-by-Elle-Kennedy/9780349447155> .
#
# <http://example.org/webshop/the-girls-9781529970982> a :Romance ;
#     :publishedBy items:Random_House ;
#     schema:author "John Bowen" ;
#     sdo:datePublished "2026-06-04" ;
#     sdo:name "The Girls" ;
#     sdo:numberOfPages 240 ;
#     sdo:price "18,4" ;
#     sdo:url <https://blackwells.co.uk/bookshop/product/The-Girls-by-John-Bowen/9781529970982> .
#
# <http://example.org/webshop/the-poison-daughter-9781911760764> a :Romance ;
#     :publishedBy items:Transworld ;
#     schema:author "Sheila Masterson" ;
#     sdo:datePublished "2026-08-18" ;
#     sdo:name "The Poison Daughter" ;
#     sdo:numberOfPages 656 ;
#     sdo:price "29,36" ;
#     sdo:url <https://blackwells.co.uk/bookshop/product/The-Poison-Daughter-by-Sheila-Masterson/9781911760764> .
#
# <http://example.org/webshop/twisted-lies-9780349448411> a :Romance ;
#     :publishedBy <http://example.org/bookshop#Little,_Brown> ;
#     schema:author "Ana Huang" ;
#     sdo:datePublished "2026-07-30" ;
#     sdo:name "Twisted Lies" ;
#     sdo:numberOfPages 554 ;
#     sdo:price "28,31" ;
#     sdo:url <https://blackwells.co.uk/bookshop/product/Twisted-Lies-by-Ana-Huang/9780349448411> .
#
# <https://w3id.org/sulo/schema/resource/ontology-schema/e2973675-d52e-4cbc-b30c-ada508eb2456> dct:title "Bookshop" .
#
# items:Atlantic_Books a items:Publisher .
#
# items:Gallery_Books a items:Publisher .
#
# items:HarperCollins_Publishers a items:Publisher .
#
# items:Headline_Publishing_Group a items:Publisher .
#
# <http://example.org/bookshop#Hodder_&_Stoughton> a items:Publisher .
#
# items:New_York_Review_Books a items:Publisher .
#
# <http://example.org/bookshop#Penguin_Random_House_Children's_UK> a items:Publisher .
#
# items:Random_House a items:Publisher .
#
# items:Scarlett_Press a items:Publisher .
#
# <http://example.org/bookshop#Little,_Brown> a items:Publisher .
#
# items:Transworld a items:Publisher .

# %%
webshop = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX bookshop: <http://example.org/bookshop#>

SELECT ?category ?subcategory ?publisher
WHERE {

    <http://example.org/webshop/the-girls-9781529970982>
        rdf:type ?subcategory .

    # ?subcategory
        rdfs:subClassOf ?category .

    <http://example.org/webshop/the-girls-9781529970982>
        bookshop:publishedBy ?publisher .
}
"""

for row in g.query(webshop):
    print(row.category, row.subcategory, row.publisher)
# Out:
# http://example.org/bookshop#GeneralFiction http://example.org/bookshop#Romance http://example.org/bookshop#Random_House
